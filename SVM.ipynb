# %% [markdown]
# <a href="https://colab.research.google.com/github/Megaprathapan/machine-Learning/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.svm import SVC,SVR
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv('/content/UniversalBank.csv')
df=df.drop(['ZIP Code','ID'],axis=1)
df.head()
# Out:
#    Age  Experience  Income  Family  CCAvg  Education  Mortgage  Personal Loan  \
# 0   25           1      49       4    1.6          1         0              0
# 1   45          19      34       3    1.5          1         0              0
# 2   39          15      11       1    1.0          1         0              0
# 3   35           9     100       1    2.7          2         0              0
# 4   35           8      45       4    1.0          2         0              0
#
#    Securities Account  CD Account  Online  CreditCard
# 0                   1           0       0           0
# 1                   1           0       0           0
# 2                   0           0       0           0
# 3                   0           0       0           0
# 4                   0           0       0           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 5000 non-null   int64
#  1   Experience          5000 non-null   int64
#  2   Income              5000 non-null   int64
#  3   Family              5000 non-null   int64
#  4   CCAvg               5000 non-null   float64
#  5   Education           5000 non-null   int64
#  6   Mortgage            5000 non-null   int64
#  7   Personal Loan       5000 non-null   int64
#  8   Securities Account  5000 non-null   int64
#  9   CD Account          5000 non-null   int64
#  10  Online              5000 non-null   int64
#  11  CreditCard          5000 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 468.9 KB

# %%
df['Income'].value_counts()
# Out:
# Income
# 44     85
# 38     84
# 81     83
# 41     82
# 39     81
#        ..
# 205     2
# 189     2
# 203     2
# 224     1
# 218     1
# Name: count, Length: 162, dtype: int64

# %%
x=df.drop(['Personal Loan'],axis=1)
columns=x.select_dtypes(include='number').columns
y=df['Personal Loan']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=SVC()
model.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model.score(xtest,ytest)
# Out:
# 0.9

# %%
model.score(xtrain,ytrain)
# Out:
# 0.9125

# %%
preprocess=ColumnTransformer(
    transformers=[
        ('sacler',StandardScaler(),columns)
    ]
)

# %%
pipeline=Pipeline(
    steps=[
        ('preprocess',preprocess),
        ('model',SVC())
    ]
)

# %%
params={
    'model__C':[0.01,0.1,1,10,100],
    'model__gamma':[0.001,0.01,0.1,1,'scale']
}

# %%
grid=GridSearchCV(pipeline,param_grid=params,cv=5)

# %%
grid.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('sacler',
#                                                                          StandardScaler(),
#                                                                          Index(['Age', 'Experience', 'Income', 'Family', 'CCAvg', 'Education',
#        'Mortgage', 'Securities Account', 'CD Account', 'Online', 'CreditCard'],
#       dtype='object'))])),
#                                        ('model', SVC())]),
#              param_grid={'model__C': [0.01, 0.1, 1, 10, 100],
#                          'model__gamma': [0.001, 0.01, 0.1, 1, 'scale']})

# %%
pred=model.predict(xtest)

# %%
f1_score(ytest,pred)
# Out:
# 0.13793103448275862

# %%
confusion_matrix(ytest,pred)
# Out:
# array([[892,   3],
#        [ 97,   8]])
